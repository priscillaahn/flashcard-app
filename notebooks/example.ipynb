# %%
from pprint import pprint

from flashcard_app.utils.load import load_cards_from_csv, create_deck

# %%
# create a deck
cards = load_cards_from_csv(
    csv_filepath="../data/example.csv",
    lang_front="ko",
    lang_back="en"
)
deck = create_deck(
    cards=cards,
    name="Puppy Poop pt.1",
    description="Vocab words from reading the Korean children's book, '강아지똥' - part 1."
)
pprint(deck)

# %%
card = deck.cards[0]
pprint(card)

# %%
card.translation

# %%
card.display_pos
